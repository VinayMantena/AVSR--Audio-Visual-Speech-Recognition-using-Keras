# %%
from os.path import isdir, join
from pathlib import Path
import pandas as pd

# Math
import numpy as np
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile
import librosa

from sklearn.decomposition import PCA

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import IPython.display as ipd
import librosa.display

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import pandas as pd

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import os
import librosa   #for audio processing
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile #for audio processing
import warnings
warnings.filterwarnings("ignore")

# %%
#English_Audio_Dataset About/1_sec_cbn_eng_about_2.wav
#Kannada_Audio_Dataset Avanu/1_sec_cbn_kan_avanu_1.wav
train_audio_path = '/media/m_snehith_reddy/Spider-Man/8th_Sem/Final_Year_Project/ALL_Audio_Video_Eng_Kan_Divided/1_sec_eng_audio_datasets_New_five/train/'
filename = 'come/1.wav'
sample_rate, samples = wavfile.read(str(train_audio_path) + filename)
# fig = plt.figure(figsize=(14, 8))
# ax1 = fig.add_subplot(211)
# ax1.set_title('Raw wave of ' + '../input/train/audio/yes/0a7c2a8d_nohash_0.wav')
# ax1.set_xlabel('time')
# ax1.set_ylabel('Amplitude')
#ax1.plot(np.linspace(0, sample_rate/len(samples), sample_rate), samples)
print(sample_rate)
print(len(samples))
# Out:
# 16000
# 16725

# %%
ipd.Audio(samples, rate=sample_rate)
print(sample_rate)
np.array(samples, dtype='float64')
# Out:
# 16000
# array([[ 0.,  0.],
#        [ 0.,  0.],
#        [ 0.,  0.],
#        ...,
#        [-3., -1.],
#        [-2.,  0.],
#        [-2.,  1.]])

# %%
samples=np.array(samples, dtype='float64')

samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
labels=os.listdir(train_audio_path)

#find count of each label and plot bar graph
no_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    no_of_recordings.append(len(waves))
    
#plot
plt.figure(figsize=(30,5))
index = np.arange(len(labels))
plt.bar(index, no_of_recordings)
plt.xlabel('Commands', fontsize=12)
plt.ylabel('No of recordings', fontsize=12)
plt.xticks(index, labels, fontsize=15, rotation=60)
plt.title('No. of recordings for each command')
plt.show()

# %%
duration_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        sample_rate, samples = wavfile.read(train_audio_path + '/' + label + '/' + wav)
        duration_of_recordings.append(float(len(samples)/sample_rate))
    
plt.hist(np.array(duration_of_recordings))
# Out:
# (array([  2.,   0.,   0., 734.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([1.024 , 1.0304, 1.0368, 1.0432, 1.0496, 1.056 , 1.0624, 1.0688,
#         1.0752, 1.0816, 1.088 ]),
#  <BarContainer object of 10 artists>)

# %%
all_wave = []
all_label = []
dct = dict()
c=0
b=0
for label in labels:
    print(label)
    
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
#         samples, sample_rate = librosa.load(train_audio_path + '/' + label + '/' + wav, sr = 16000)
#         samples = librosa.resample(samples, sample_rate, 8000)
#         #print(len(samples))
#         dct[len(samples)] = dct.get(len(samples),0) + 1
#         b+=1
#         if(len(samples)== 8363):
            
#             c+=1
#             all_wave.append(samples)
#             all_label.append(label)
        X, sample_rate = librosa.load(train_audio_path + '/' + label + '/' + wav, sr = 16000)
        stft = np.abs(librosa.stft(X))
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
        chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
        mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
        contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
        tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X),sr=sample_rate).T,axis=0)
        feature_array = np.hstack([mfccs,chroma,mel,contrast,tonnetz])
        feature_vector  = np.around(feature_array,decimals=3)
        all_wave.append(feature_vector)
        all_label.append(label)
#print(dct)
print(dict(sorted(dct.items(), key=lambda item: item[1])))
print("len = ", len(dct))
print("c = ",c,b)
# Out:
# About
# Bad
# bottle
# come
# cow
# good
# pencil
# read
# where
# {}
# len =  0
# c =  0 0

# %%
print(len(all_wave))
# Out:
# 737

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y=le.fit_transform(all_label)
classes= list(le.classes_)

# %%
from keras.utils import np_utils
y=np_utils.to_categorical(y, num_classes=len(labels))

# %%
#all_wave = np.array(all_wave).reshape(-1,8363,1)

all_wave = np.array(all_wave).reshape(-1,193,)

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(np.array(all_wave),np.array(y),stratify=y,test_size = 0.3,train_size=0.7,random_state=777,shuffle=True)

# %%
y_val1 = list()
for i in y_val:
    count = 0
    for j in i:
        if( j == 1):
            y_val1.append(count);
        count +=1;

y_tr1 = list()
for i in y_tr:
    count = 0
    for j in i:
        if( j == 1):
            y_tr1.append(count);
        count +=1;

dct = dict()
for i in y_val1:
    dct[i] = dct.get(i,0) + 1
print(dict(sorted(dct.items(), key=lambda item: item[1])))

print("y_tr1 rows, cols =", len(y_tr1))
print("y_val1 rows, cols =", len(y_val1))
print("x_tr rows, cols =", len(x_tr), len(x_tr[0]))
print("x_val rows, cols =", len(x_val), len(x_val[0]))

# print("y_val1 =",y_val1)
x_train_dup = x_tr
y_train_dup = y_tr1

x_val_dup = x_val
y_val_dup = y_val1

# x_train_list = list(list())
# for i in range(0,len(x_tr)):
#     tmp = list()
#     for j in range(0,len(x_tr[i])):
#         tmp.append(x_tr[i][j])
#     x_train_list.append(tmp)
    
# print(x_train_list)
# print(x_tr)



dct = dict()
for i in range(0,9):
    count = 0
    tmp = list()
    for j in range(0, len(y_val1)):
        if(y_val1[j] == i):
            count +=1;
        if(count > 21 and y_val1[j] == i):
            x_train_dup = np.vstack([x_train_dup, x_val_dup[j]])
            y_train_dup = np.append(y_train_dup, y_val1[j])
            
            tmp.append(j)
    dct[i] = tmp

# print(len(x_train_dup), len(x_tr), len(y_train_dup), len(y_tr1))
# print(len(x_val_dup), len(x_val), len(y_val_dup), len(y_val1))
# #print(dct)
#print(dct.values())
index_list = list()
for i in dct.values():
    for j in i:
        index_list.append(j)
index_list.sort(reverse=True)
print(index_list)
for i in index_list:
    x_val_dup = np.delete(x_val_dup, (i), axis=0)
    y_val1.pop(i)
print(len(x_train_dup), len(x_tr), len(y_train_dup), len(y_tr1))
print(len(x_val_dup), len(x_val), len(y_val_dup), len(y_val1))





from keras.utils import np_utils, generic_utils

y_train_dup, y_val_dup = [np_utils.to_categorical(x) for x in (y_train_dup, y_val_dup)]
# Out:
# {0: 23, 3: 24, 1: 24, 2: 24, 6: 25, 4: 25, 7: 25, 5: 26, 8: 26}
# y_tr1 rows, cols = 515
# y_val1 rows, cols = 222
# x_tr rows, cols = 515 193
# x_val rows, cols = 222 193
# [221, 220, 219, 218, 217, 216, 215, 214, 213, 212, 211, 210, 209, 207, 206, 205, 204, 203, 202, 201, 200, 199, 198, 197, 196, 195, 193, 189, 188, 179, 174, 171, 169]
# 548 515 548 515
# 189 222 189 189

# %%
from keras.layers import Dense, Dropout, Flatten, Conv1D, Input, MaxPooling1D, BatchNormalization, Bidirectional
from keras.models import Model, Sequential
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
K.clear_session()

# from keras.layers.core import Activation, Dropout, Dense
# from keras.layers import Flatten, LSTM

# model = Sequential()
# model.add(Dense(units=256, activation='relu', input_shape=(193,)))
# model.add(Dense(128, activation='relu'))
# model.add(Dense(128, activation="relu"))
# model.add(Dense(64, activation="relu"))
# model.add(Dense(9, activation='softmax'))
# model.summary()

inputs = Input(shape=(193,1))

# #First Conv1D layer
# conv = Conv1D(8,13, padding='valid', activation='relu', strides=1)(inputs)
# conv = MaxPooling1D(3)(conv)
# conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # conv = Dropout(0.3)(conv)

# #Second Conv1D layer
# conv = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # conv = Dropout(0.3)(conv)

# # #Third Conv1D layer
# # conv = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(conv)
# # conv = MaxPooling1D(3)(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # conv = Dropout(0.3)(conv)

# # #Fourth Conv1D layer
# # conv = Conv1D(64, 7, padding='valid', activation='relu', strides=1)(conv)
# # conv = MaxPooling1D(3)(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # conv = Dropout(0.3)(conv)



# #Flatten layer
# conv = Flatten()(conv)

# #Dense Layer 1
# conv = Dense(256, activation='relu')(conv)
# conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # conv = Dropout(0.3)(conv)

# # #Dense Layer 2
# # conv = Dense(512, activation='relu')(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # # conv = Dropout(0.3)(conv)

# # #Dense Layer 3
# # conv = Dense(1024, activation='relu')(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # # conv = Dropout(0.3)(conv)

# # #Dense Layer 4
# # conv = Dense(1024, activation='relu')(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # # conv = Dropout(0.3)(conv)

# outputs = Dense(len(labels), activation='softmax')(conv)

# model = Model(inputs, outputs)
# model.summary()









conv = Conv1D(16,13, padding='valid', activation='relu', strides=1)(inputs)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)
conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
conv = Flatten()(conv)
x = Dense(units=1024, activation='relu')(conv)
x1 = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(x)
x1 = Dropout(0.3)(x1)
x1 = Dense(512, activation='relu')(x1)
x1 = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(x1)
x1 = Dropout(0.3)(x1)
x1 = Dense(256, activation='relu')(x1)
x1 = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(x1)
x1 = Dropout(0.3)(x1)
x1 = Dense(128, activation='relu')(x1)

outputs = Dense(len(labels), activation='softmax')(x1)

model = Model(inputs, outputs)
model.summary()












# #First Conv1D layer
# conv = Conv1D(8,13, padding='valid', activation='relu', strides=1)(inputs)
# conv = MaxPooling1D(3)(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# conv = Dropout(0.2)(conv)

# #Second Conv1D layer
# conv = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# conv = Dropout(0.2)(conv)

# #Third Conv1D layer
# conv = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# conv = Dropout(0.2)(conv)

# #Fourth Conv1D layer
# conv = Conv1D(64, 7, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# conv = Dropout(0.2)(conv)


# #Flatten layer
# conv = Flatten()(conv)

# #Dense Layer 1
# conv = Dense(1024, activation='relu')(conv)
# conv = Dropout(0.2)(conv)

# #Dense Layer 2
# conv = Dense(1024, activation='relu')(conv)
# conv = Dropout(0.2)(conv)

# # #Dense Layer 2
# # conv = Dense(32, activation='relu')(conv)
# # conv = Dropout(0.3)(conv)

# # #Dense Layer 2
# # conv = Dense(64, activation='relu')(conv)
# # conv = Dropout(0.3)(conv)

# outputs = Dense(len(labels), activation='softmax')(conv)

# model = Model(inputs, outputs)
# model.summary()


# #First Conv1D layer
# conv = Conv1D(8,13, padding='valid', activation='relu', strides=1)(inputs)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.3)(conv)

# #Second Conv1D layer
# conv = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.3)(conv)

# #Third Conv1D layer
# conv = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.3)(conv)

# #Fourth Conv1D layer
# conv = Conv1D(64, 7, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.3)(conv)

# #Flatten layer
# conv = Flatten()(conv)

# #Dense Layer 1
# conv = Dense(512, activation='relu')(conv)
# conv = Dropout(0.3)(conv)

# #Dense Layer 2
# conv = Dense(128, activation='relu')(conv)
# conv = Dropout(0.3)(conv)

# #Dense Layer 2
# conv = Dense(64, activation='relu')(conv)
# conv = Dropout(0.3)(conv)

# outputs = Dense(len(labels), activation='softmax')(conv)

# model = Model(inputs, outputs)
# model.summary()


# #First Conv1D layer
# conv = Conv1D(8,13, padding='valid', activation='relu', strides=1)(inputs)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.2)(conv)

# #Second Conv1D layer
# conv = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.2)(conv)

# #Third Conv1D layer
# conv = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.2)(conv)

# #Fourth Conv1D layer
# conv = Conv1D(64, 7, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.2)(conv)

# #Flatten layer
# conv = Flatten()(conv)

# #Dense Layer 1
# conv = Dense(256, activation='relu')(conv)
# conv = Dropout(0.2)(conv)

# #Dense Layer 2
# conv = Dense(128, activation='relu')(conv)
# conv = Dropout(0.2)(conv)

# outputs = Dense(len(labels), activation='softmax')(conv)

# model = Model(inputs, outputs)
# model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 193, 1)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 181, 16)           224
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 60, 16)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 16)            0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 60, 16)            64
# _________________________________________________________________
# flatten (Flatten)            (None, 960)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              984064
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 9)                 1161
# =================================================================
# Total params: 1,681,705
# Trainable params: 1,678,089
# Non-trainable params: 3,616
# _________________________________________________________________

# %%
import keras
optimizer = keras.optimizers.Adam(lr=0.001)
model.compile(loss='categorical_crossentropy',optimizer= 'adam',metrics=['accuracy'])

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.0001) 
mc = ModelCheckpoint('best_model.hdf5', monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history=model.fit(x_train_dup, y_train_dup ,epochs=200, batch_size=32, validation_data=(x_val_dup,y_val_dup))
# Out:
# Epoch 1/200
# 18/18 [==============================] - 2s 30ms/step - loss: 2.8017 - accuracy: 0.1032 - val_loss: 2.3249 - val_accuracy: 0.1481
# Epoch 2/200
# 18/18 [==============================] - 0s 17ms/step - loss: 2.0987 - accuracy: 0.2634 - val_loss: 2.1339 - val_accuracy: 0.1852
# Epoch 3/200
# 18/18 [==============================] - 0s 17ms/step - loss: 1.7191 - accuracy: 0.4128 - val_loss: 1.8491 - val_accuracy: 0.3069
# Epoch 4/200
# 18/18 [==============================] - 0s 17ms/step - loss: 1.6444 - accuracy: 0.4122 - val_loss: 1.4756 - val_accuracy: 0.4180
# Epoch 5/200
# 18/18 [==============================] - 0s 18ms/step - loss: 1.5304 - accuracy: 0.4127 - val_loss: 1.3117 - val_accuracy: 0.4868
# Epoch 6/200
# 18/18 [==============================] - 0s 17ms/step - loss: 1.3432 - accuracy: 0.5066 - val_loss: 1.1807 - val_accuracy: 0.5503
# Epoch 7/200
# 18/18 [==============================] - 0s 17ms/step - loss: 1.2752 - accuracy: 0.5264 - val_loss: 1.0309 - val_accuracy: 0.6349
# Epoch 8/200
# 18/18 [==============================] - 0s 17ms/step - loss: 1.3563 - accuracy: 0.5309 - val_loss: 0.9321 - val_accuracy: 0.6720
# Epoch 9/200
# 18/18 [==============================] - 0s 27ms/step - loss: 1.1727 - accuracy: 0.5813 - val_loss: 0.8318 - val_accuracy: 0.6984
# Epoch 10/200
# 18/18 [==============================] - 0s 17ms/step - loss: 1.1315 - accuracy: 0.5439 - val_loss: 0.7865 - val_accuracy: 0.7302
# Epoch 11/200
# 18/18 [==============================] - 0s 18ms/step - loss: 1.0802 - accuracy: 0.6157 - val_loss: 0.8069 - val_accuracy: 0.7090
# Epoch 12/200
# 18/18 [==============================] - 0s 17ms/step - loss: 1.0833 - accuracy: 0.6024 - val_loss: 0.7111 - val_accuracy: 0.7619
# Epoch 13/200
# 18/18 [==============================] - 0s 17ms/step - loss: 1.0449 - accuracy: 0.5906 - val_loss: 0.6538 - val_accuracy: 0.7831
# Epoch 14/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.9104 - accuracy: 0.6606 - val_loss: 0.6867 - val_accuracy: 0.7619
# Epoch 15/200
# 18/18 [==============================] - 0s 17ms/step - loss: 1.0146 - accuracy: 0.6258 - val_loss: 0.6670 - val_accuracy: 0.7831
# Epoch 16/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.7982 - accuracy: 0.7279 - val_loss: 0.6933 - val_accuracy: 0.7619
# Epoch 17/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.8445 - accuracy: 0.6790 - val_loss: 0.7857 - val_accuracy: 0.7249
# Epoch 18/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.8085 - accuracy: 0.7048 - val_loss: 0.6656 - val_accuracy: 0.7566
# Epoch 19/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.8770 - accuracy: 0.6763 - val_loss: 0.7060 - val_accuracy: 0.7566
# Epoch 20/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.7448 - accuracy: 0.6964 - val_loss: 0.6978 - val_accuracy: 0.7407
# Epoch 21/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.7515 - accuracy: 0.7293 - val_loss: 0.6227 - val_accuracy: 0.7460
# Epoch 22/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.7490 - accuracy: 0.7273 - val_loss: 0.6220 - val_accuracy: 0.7778
# Epoch 23/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.7947 - accuracy: 0.6947 - val_loss: 0.5763 - val_accuracy: 0.7937
# Epoch 24/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.6984 - accuracy: 0.7385 - val_loss: 0.6105 - val_accuracy: 0.7778
# Epoch 25/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.6455 - accuracy: 0.7667 - val_loss: 0.5777 - val_accuracy: 0.8095
# Epoch 26/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.7146 - accuracy: 0.7329 - val_loss: 0.6026 - val_accuracy: 0.7884
# Epoch 27/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.8116 - accuracy: 0.7055 - val_loss: 0.4830 - val_accuracy: 0.7989
# Epoch 28/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.7071 - accuracy: 0.7203 - val_loss: 0.5073 - val_accuracy: 0.8201
# Epoch 29/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.6277 - accuracy: 0.7444 - val_loss: 0.4778 - val_accuracy: 0.8413
# Epoch 30/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.6881 - accuracy: 0.7751 - val_loss: 0.4675 - val_accuracy: 0.8360
# Epoch 31/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.6026 - accuracy: 0.7729 - val_loss: 0.4693 - val_accuracy: 0.8201
# Epoch 32/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.7285 - accuracy: 0.7501 - val_loss: 0.4519 - val_accuracy: 0.8413
# Epoch 33/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.5907 - accuracy: 0.7834 - val_loss: 0.5404 - val_accuracy: 0.7725
# Epoch 34/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.5647 - accuracy: 0.8066 - val_loss: 0.5006 - val_accuracy: 0.8095
# Epoch 35/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.5933 - accuracy: 0.7895 - val_loss: 0.6407 - val_accuracy: 0.7302
# Epoch 36/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.5878 - accuracy: 0.7786 - val_loss: 0.5328 - val_accuracy: 0.7778
# Epoch 37/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.6213 - accuracy: 0.7720 - val_loss: 0.5329 - val_accuracy: 0.7778
# Epoch 38/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.6417 - accuracy: 0.7823 - val_loss: 0.4625 - val_accuracy: 0.8307
# Epoch 39/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.6706 - accuracy: 0.7179 - val_loss: 0.4229 - val_accuracy: 0.8360
# Epoch 40/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.5937 - accuracy: 0.7519 - val_loss: 0.4624 - val_accuracy: 0.8307
# Epoch 41/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.5068 - accuracy: 0.8383 - val_loss: 0.4658 - val_accuracy: 0.8413
# Epoch 42/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.5734 - accuracy: 0.8154 - val_loss: 0.4270 - val_accuracy: 0.8466
# Epoch 43/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.6036 - accuracy: 0.7786 - val_loss: 0.3912 - val_accuracy: 0.8466
# Epoch 44/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.5499 - accuracy: 0.8198 - val_loss: 0.4056 - val_accuracy: 0.8360
# Epoch 45/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4896 - accuracy: 0.8172 - val_loss: 0.4434 - val_accuracy: 0.8466
# Epoch 46/200
# 18/18 [==============================] - 0s 24ms/step - loss: 0.5504 - accuracy: 0.8067 - val_loss: 0.3958 - val_accuracy: 0.8519
# Epoch 47/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.4278 - accuracy: 0.8318 - val_loss: 0.4345 - val_accuracy: 0.8254
# Epoch 48/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.5526 - accuracy: 0.7902 - val_loss: 0.4339 - val_accuracy: 0.8413
# Epoch 49/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.5042 - accuracy: 0.8188 - val_loss: 0.4002 - val_accuracy: 0.8571
# Epoch 50/200
# 18/18 [==============================] - 0s 20ms/step - loss: 0.5907 - accuracy: 0.7871 - val_loss: 0.3928 - val_accuracy: 0.8571
# Epoch 51/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.4880 - accuracy: 0.8345 - val_loss: 0.4160 - val_accuracy: 0.8519
# Epoch 52/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.4728 - accuracy: 0.8108 - val_loss: 0.3386 - val_accuracy: 0.8677
# Epoch 53/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.4583 - accuracy: 0.8384 - val_loss: 0.3391 - val_accuracy: 0.8730
# Epoch 54/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4885 - accuracy: 0.8025 - val_loss: 0.4105 - val_accuracy: 0.8307
# Epoch 55/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.3975 - accuracy: 0.8536 - val_loss: 0.3673 - val_accuracy: 0.8466
# Epoch 56/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.3987 - accuracy: 0.8515 - val_loss: 0.4183 - val_accuracy: 0.8413
# Epoch 57/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4529 - accuracy: 0.8319 - val_loss: 0.3636 - val_accuracy: 0.8466
# Epoch 58/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4484 - accuracy: 0.8370 - val_loss: 0.2847 - val_accuracy: 0.9048
# Epoch 59/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4529 - accuracy: 0.8351 - val_loss: 0.3033 - val_accuracy: 0.8783
# Epoch 60/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4495 - accuracy: 0.8252 - val_loss: 0.3818 - val_accuracy: 0.8677
# Epoch 61/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.4892 - accuracy: 0.8134 - val_loss: 0.2915 - val_accuracy: 0.8783
# Epoch 62/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3886 - accuracy: 0.8534 - val_loss: 0.2932 - val_accuracy: 0.8783
# Epoch 63/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.4787 - accuracy: 0.8196 - val_loss: 0.3489 - val_accuracy: 0.8571
# Epoch 64/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4841 - accuracy: 0.8229 - val_loss: 0.4394 - val_accuracy: 0.8201
# Epoch 65/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.6188 - accuracy: 0.7770 - val_loss: 0.3909 - val_accuracy: 0.8307
# Epoch 66/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4840 - accuracy: 0.8364 - val_loss: 0.3486 - val_accuracy: 0.8783
# Epoch 67/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.5470 - accuracy: 0.7994 - val_loss: 0.3110 - val_accuracy: 0.8942
# Epoch 68/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.5376 - accuracy: 0.8118 - val_loss: 0.3494 - val_accuracy: 0.8889
# Epoch 69/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4864 - accuracy: 0.8463 - val_loss: 0.4338 - val_accuracy: 0.8360
# Epoch 70/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4925 - accuracy: 0.8375 - val_loss: 0.3406 - val_accuracy: 0.8571
# Epoch 71/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3843 - accuracy: 0.8667 - val_loss: 0.3285 - val_accuracy: 0.8571
# Epoch 72/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4656 - accuracy: 0.8271 - val_loss: 0.3827 - val_accuracy: 0.8466
# Epoch 73/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3966 - accuracy: 0.8561 - val_loss: 0.3924 - val_accuracy: 0.8413
# Epoch 74/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.4464 - accuracy: 0.8402 - val_loss: 0.3813 - val_accuracy: 0.8466
# Epoch 75/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.4867 - accuracy: 0.8292 - val_loss: 0.3506 - val_accuracy: 0.8571
# Epoch 76/200
# 18/18 [==============================] - 0s 23ms/step - loss: 0.4786 - accuracy: 0.8223 - val_loss: 0.2967 - val_accuracy: 0.8677
# Epoch 77/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3842 - accuracy: 0.8666 - val_loss: 0.3148 - val_accuracy: 0.8519
# Epoch 78/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4417 - accuracy: 0.8377 - val_loss: 0.2894 - val_accuracy: 0.8889
# Epoch 79/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.4459 - accuracy: 0.8555 - val_loss: 0.2874 - val_accuracy: 0.8783
# Epoch 80/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4002 - accuracy: 0.8597 - val_loss: 0.3008 - val_accuracy: 0.8783
# Epoch 81/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.4130 - accuracy: 0.8550 - val_loss: 0.3233 - val_accuracy: 0.8624
# Epoch 82/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.4501 - accuracy: 0.8314 - val_loss: 0.4039 - val_accuracy: 0.8413
# Epoch 83/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.4101 - accuracy: 0.8635 - val_loss: 0.3572 - val_accuracy: 0.8466
# Epoch 84/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4301 - accuracy: 0.8309 - val_loss: 0.2986 - val_accuracy: 0.8836
# Epoch 85/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4362 - accuracy: 0.8060 - val_loss: 0.2954 - val_accuracy: 0.8942
# Epoch 86/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4152 - accuracy: 0.8396 - val_loss: 0.3082 - val_accuracy: 0.9048
# Epoch 87/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4228 - accuracy: 0.8558 - val_loss: 0.3684 - val_accuracy: 0.8571
# Epoch 88/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.5042 - accuracy: 0.8174 - val_loss: 0.3574 - val_accuracy: 0.8624
# Epoch 89/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3852 - accuracy: 0.8457 - val_loss: 0.2939 - val_accuracy: 0.8889
# Epoch 90/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3426 - accuracy: 0.8756 - val_loss: 0.3449 - val_accuracy: 0.8836
# Epoch 91/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3566 - accuracy: 0.8825 - val_loss: 0.2772 - val_accuracy: 0.8942
# Epoch 92/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4236 - accuracy: 0.8419 - val_loss: 0.2900 - val_accuracy: 0.8783
# Epoch 93/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3500 - accuracy: 0.8576 - val_loss: 0.3015 - val_accuracy: 0.8519
# Epoch 94/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4012 - accuracy: 0.8659 - val_loss: 0.3218 - val_accuracy: 0.8783
# Epoch 95/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4922 - accuracy: 0.8273 - val_loss: 0.3541 - val_accuracy: 0.8677
# Epoch 96/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3850 - accuracy: 0.8745 - val_loss: 0.3395 - val_accuracy: 0.8624
# Epoch 97/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4049 - accuracy: 0.8784 - val_loss: 0.3673 - val_accuracy: 0.8624
# Epoch 98/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4560 - accuracy: 0.8536 - val_loss: 0.3824 - val_accuracy: 0.8519
# Epoch 99/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4474 - accuracy: 0.8137 - val_loss: 0.3357 - val_accuracy: 0.8571
# Epoch 100/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3156 - accuracy: 0.8974 - val_loss: 0.2966 - val_accuracy: 0.8730
# Epoch 101/200
# 18/18 [==============================] - 0s 24ms/step - loss: 0.3827 - accuracy: 0.8647 - val_loss: 0.2833 - val_accuracy: 0.8942
# Epoch 102/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3450 - accuracy: 0.8867 - val_loss: 0.2915 - val_accuracy: 0.8836
# Epoch 103/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.4493 - accuracy: 0.8548 - val_loss: 0.3292 - val_accuracy: 0.8836
# Epoch 104/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3119 - accuracy: 0.8848 - val_loss: 0.4391 - val_accuracy: 0.8466
# Epoch 105/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4132 - accuracy: 0.8616 - val_loss: 0.3149 - val_accuracy: 0.8889
# Epoch 106/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4590 - accuracy: 0.8490 - val_loss: 0.2902 - val_accuracy: 0.8889
# Epoch 107/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3842 - accuracy: 0.8570 - val_loss: 0.2976 - val_accuracy: 0.8836
# Epoch 108/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.4273 - accuracy: 0.8634 - val_loss: 0.3059 - val_accuracy: 0.8942
# Epoch 109/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3367 - accuracy: 0.8892 - val_loss: 0.2902 - val_accuracy: 0.8942
# Epoch 110/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.4168 - accuracy: 0.8626 - val_loss: 0.2430 - val_accuracy: 0.8995
# Epoch 111/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3185 - accuracy: 0.8751 - val_loss: 0.2606 - val_accuracy: 0.8889
# Epoch 112/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3460 - accuracy: 0.8754 - val_loss: 0.2701 - val_accuracy: 0.9048
# Epoch 113/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3490 - accuracy: 0.8758 - val_loss: 0.3560 - val_accuracy: 0.8730
# Epoch 114/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3683 - accuracy: 0.8703 - val_loss: 0.3117 - val_accuracy: 0.8995
# Epoch 115/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.3464 - accuracy: 0.9065 - val_loss: 0.3229 - val_accuracy: 0.8889
# Epoch 116/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3628 - accuracy: 0.8808 - val_loss: 0.3461 - val_accuracy: 0.8624
# Epoch 117/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2417 - accuracy: 0.9013 - val_loss: 0.2999 - val_accuracy: 0.8889
# Epoch 118/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3410 - accuracy: 0.8688 - val_loss: 0.3989 - val_accuracy: 0.8677
# Epoch 119/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.3554 - accuracy: 0.8710 - val_loss: 0.3595 - val_accuracy: 0.8995
# Epoch 120/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.3353 - accuracy: 0.8797 - val_loss: 0.2944 - val_accuracy: 0.8889
# Epoch 121/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3221 - accuracy: 0.8870 - val_loss: 0.2781 - val_accuracy: 0.8889
# Epoch 122/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.3513 - accuracy: 0.8861 - val_loss: 0.2065 - val_accuracy: 0.9153
# Epoch 123/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3637 - accuracy: 0.8658 - val_loss: 0.2673 - val_accuracy: 0.8995
# Epoch 124/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.4174 - accuracy: 0.8583 - val_loss: 0.2830 - val_accuracy: 0.9048
# Epoch 125/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3800 - accuracy: 0.8729 - val_loss: 0.3080 - val_accuracy: 0.8571
# Epoch 126/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3052 - accuracy: 0.8832 - val_loss: 0.2900 - val_accuracy: 0.8889
# Epoch 127/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3769 - accuracy: 0.8799 - val_loss: 0.2555 - val_accuracy: 0.8995
# Epoch 128/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2975 - accuracy: 0.8990 - val_loss: 0.2793 - val_accuracy: 0.8889
# Epoch 129/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3222 - accuracy: 0.8856 - val_loss: 0.3686 - val_accuracy: 0.8571
# Epoch 130/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3747 - accuracy: 0.8737 - val_loss: 0.3443 - val_accuracy: 0.8783
# Epoch 131/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.2404 - accuracy: 0.9239 - val_loss: 0.3138 - val_accuracy: 0.8677
# Epoch 132/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3037 - accuracy: 0.8974 - val_loss: 0.3345 - val_accuracy: 0.8466
# Epoch 133/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3181 - accuracy: 0.8797 - val_loss: 0.3069 - val_accuracy: 0.8783
# Epoch 134/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3531 - accuracy: 0.8749 - val_loss: 0.3564 - val_accuracy: 0.8730
# Epoch 135/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3614 - accuracy: 0.8807 - val_loss: 0.3364 - val_accuracy: 0.8571
# Epoch 136/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2986 - accuracy: 0.8675 - val_loss: 0.3058 - val_accuracy: 0.8730
# Epoch 137/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2923 - accuracy: 0.9137 - val_loss: 0.2804 - val_accuracy: 0.9048
# Epoch 138/200
# 18/18 [==============================] - 0s 24ms/step - loss: 0.4252 - accuracy: 0.8538 - val_loss: 0.2653 - val_accuracy: 0.9312
# Epoch 139/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3360 - accuracy: 0.8785 - val_loss: 0.3467 - val_accuracy: 0.8677
# Epoch 140/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3868 - accuracy: 0.8549 - val_loss: 0.2912 - val_accuracy: 0.8995
# Epoch 141/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2962 - accuracy: 0.8891 - val_loss: 0.2457 - val_accuracy: 0.9101
# Epoch 142/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.3772 - accuracy: 0.8520 - val_loss: 0.2812 - val_accuracy: 0.8889
# Epoch 143/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.3376 - accuracy: 0.8679 - val_loss: 0.2585 - val_accuracy: 0.9048
# Epoch 144/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.4028 - accuracy: 0.8573 - val_loss: 0.2711 - val_accuracy: 0.8836
# Epoch 145/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3415 - accuracy: 0.8828 - val_loss: 0.2163 - val_accuracy: 0.9101
# Epoch 146/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2989 - accuracy: 0.8948 - val_loss: 0.2505 - val_accuracy: 0.9101
# Epoch 147/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3971 - accuracy: 0.8607 - val_loss: 0.2896 - val_accuracy: 0.9048
# Epoch 148/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2919 - accuracy: 0.8934 - val_loss: 0.3075 - val_accuracy: 0.8995
# Epoch 149/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3910 - accuracy: 0.8592 - val_loss: 0.2220 - val_accuracy: 0.9206
# Epoch 150/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3034 - accuracy: 0.9000 - val_loss: 0.2611 - val_accuracy: 0.9206
# Epoch 151/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2993 - accuracy: 0.8983 - val_loss: 0.2325 - val_accuracy: 0.9101
# Epoch 152/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2849 - accuracy: 0.9075 - val_loss: 0.2912 - val_accuracy: 0.8942
# Epoch 153/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2703 - accuracy: 0.8890 - val_loss: 0.2982 - val_accuracy: 0.8889
# Epoch 154/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3205 - accuracy: 0.8876 - val_loss: 0.3079 - val_accuracy: 0.8836
# Epoch 155/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3678 - accuracy: 0.8695 - val_loss: 0.2660 - val_accuracy: 0.8942
# Epoch 156/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3936 - accuracy: 0.8480 - val_loss: 0.3506 - val_accuracy: 0.8466
# Epoch 157/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2746 - accuracy: 0.9104 - val_loss: 0.3383 - val_accuracy: 0.8836
# Epoch 158/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3042 - accuracy: 0.9127 - val_loss: 0.2917 - val_accuracy: 0.8836
# Epoch 159/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2534 - accuracy: 0.9118 - val_loss: 0.3613 - val_accuracy: 0.8677
# Epoch 160/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3543 - accuracy: 0.8938 - val_loss: 0.3399 - val_accuracy: 0.8519
# Epoch 161/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2681 - accuracy: 0.9043 - val_loss: 0.3625 - val_accuracy: 0.8519
# Epoch 162/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2456 - accuracy: 0.9089 - val_loss: 0.3219 - val_accuracy: 0.8730
# Epoch 163/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2947 - accuracy: 0.9089 - val_loss: 0.3386 - val_accuracy: 0.8730
# Epoch 164/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2150 - accuracy: 0.9402 - val_loss: 0.3242 - val_accuracy: 0.8624
# Epoch 165/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2702 - accuracy: 0.9058 - val_loss: 0.3155 - val_accuracy: 0.8783
# Epoch 166/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.2981 - accuracy: 0.9062 - val_loss: 0.3369 - val_accuracy: 0.8677
# Epoch 167/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3387 - accuracy: 0.8732 - val_loss: 0.3799 - val_accuracy: 0.8677
# Epoch 168/200
# 18/18 [==============================] - 0s 24ms/step - loss: 0.2719 - accuracy: 0.9110 - val_loss: 0.3911 - val_accuracy: 0.8624
# Epoch 169/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.2656 - accuracy: 0.9072 - val_loss: 0.3675 - val_accuracy: 0.8677
# Epoch 170/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3025 - accuracy: 0.8967 - val_loss: 0.3491 - val_accuracy: 0.8730
# Epoch 171/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2792 - accuracy: 0.8827 - val_loss: 0.2988 - val_accuracy: 0.8836
# Epoch 172/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2337 - accuracy: 0.9222 - val_loss: 0.3312 - val_accuracy: 0.8836
# Epoch 173/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3709 - accuracy: 0.8546 - val_loss: 0.3740 - val_accuracy: 0.8783
# Epoch 174/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3108 - accuracy: 0.8867 - val_loss: 0.3317 - val_accuracy: 0.8942
# Epoch 175/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2920 - accuracy: 0.8962 - val_loss: 0.3243 - val_accuracy: 0.8942
# Epoch 176/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2610 - accuracy: 0.9121 - val_loss: 0.3118 - val_accuracy: 0.8783
# Epoch 177/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3843 - accuracy: 0.8694 - val_loss: 0.3176 - val_accuracy: 0.8889
# Epoch 178/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2804 - accuracy: 0.8983 - val_loss: 0.2778 - val_accuracy: 0.9048
# Epoch 179/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2650 - accuracy: 0.8906 - val_loss: 0.2289 - val_accuracy: 0.9048
# Epoch 180/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2107 - accuracy: 0.9183 - val_loss: 0.2159 - val_accuracy: 0.9206
# Epoch 181/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.2411 - accuracy: 0.9261 - val_loss: 0.2176 - val_accuracy: 0.9101
# Epoch 182/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2010 - accuracy: 0.9296 - val_loss: 0.2108 - val_accuracy: 0.9312
# Epoch 183/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.2623 - accuracy: 0.9113 - val_loss: 0.2564 - val_accuracy: 0.8942
# Epoch 184/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2524 - accuracy: 0.9237 - val_loss: 0.2622 - val_accuracy: 0.8889
# Epoch 185/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3191 - accuracy: 0.9098 - val_loss: 0.2735 - val_accuracy: 0.8995
# Epoch 186/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.3013 - accuracy: 0.9098 - val_loss: 0.3439 - val_accuracy: 0.8889
# Epoch 187/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2318 - accuracy: 0.8915 - val_loss: 0.2751 - val_accuracy: 0.8995
# Epoch 188/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2731 - accuracy: 0.9025 - val_loss: 0.3070 - val_accuracy: 0.8889
# Epoch 189/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.2805 - accuracy: 0.9032 - val_loss: 0.2389 - val_accuracy: 0.9206
# Epoch 190/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.3137 - accuracy: 0.9011 - val_loss: 0.2533 - val_accuracy: 0.8995
# Epoch 191/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2432 - accuracy: 0.9069 - val_loss: 0.2272 - val_accuracy: 0.8995
# Epoch 192/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.3033 - accuracy: 0.8744 - val_loss: 0.2114 - val_accuracy: 0.9206
# Epoch 193/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2912 - accuracy: 0.8890 - val_loss: 0.2566 - val_accuracy: 0.9048
# Epoch 194/200
# 18/18 [==============================] - 0s 23ms/step - loss: 0.2533 - accuracy: 0.9108 - val_loss: 0.2704 - val_accuracy: 0.9153
# Epoch 195/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.2683 - accuracy: 0.9140 - val_loss: 0.2569 - val_accuracy: 0.9101
# Epoch 196/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2551 - accuracy: 0.9052 - val_loss: 0.2800 - val_accuracy: 0.8942
# Epoch 197/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.2698 - accuracy: 0.9117 - val_loss: 0.2455 - val_accuracy: 0.8995
# Epoch 198/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2771 - accuracy: 0.8985 - val_loss: 0.2019 - val_accuracy: 0.9206
# Epoch 199/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.2879 - accuracy: 0.9038 - val_loss: 0.2432 - val_accuracy: 0.9206
# Epoch 200/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.1807 - accuracy: 0.9367 - val_loss: 0.2052 - val_accuracy: 0.9153

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('Audio_English Model accuracy.jpg')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train_loss', 'val_loss'], loc='upper right')
plt.savefig('Audio_English Model Loss.jpg')
plt.show()

# %%
predict_prob=model.predict(x_val_dup)
predict_classes=np.argmax(predict_prob,axis=1)
predict_classes
score, acc = model.evaluate(x_val_dup, y_val_dup)
# Out:
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2052 - accuracy: 0.9153

# %%
tmp = list()
for i in y_val_dup:
    count = 0
    for j in i:
        if( j == 1):
            tmp.append(count);
        count +=1;
# print(tmp)
from sklearn.preprocessing import LabelEncoder
from keras.models import load_model
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
import seaborn as sns
words_list = ['About','Bad','Bottle', 'Come','Cow', 'Good','Pencil', 'Read', 'Where']
lb_make = LabelEncoder()
y_pred = lb_make.fit_transform(predict_classes)
Y_Test = lb_make.fit_transform(tmp)
cm = confusion_matrix(Y_Test, y_pred)
cm_df = pd.DataFrame(cm,index =words_list,columns = words_list)
plt.figure(figsize=(10,8))
sns.heatmap(cm_df, annot=True, cmap="Blues")
plt.title('Test accuracy of English dataset {}'.format(acc))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.savefig('Audio_English Confusion Matrix.jpg')
plt.show()

# %%
from sklearn.metrics import classification_report
y_pred = lb_make.fit_transform(predict_classes)
Y_Test = lb_make.fit_transform(Y_Test)
print(classification_report(Y_Test, y_pred, target_names=words_list))
# Out:
#               precision    recall  f1-score   support
#
#        About       0.85      0.81      0.83        21
#          Bad       0.88      1.00      0.93        21
#       Bottle       1.00      0.86      0.92        21
#         Come       0.90      0.86      0.88        21
#          Cow       0.78      0.86      0.82        21
#         Good       0.95      0.95      0.95        21
#       Pencil       1.00      1.00      1.00        21
#         Read       1.00      0.90      0.95        21
#        Where       0.91      1.00      0.95        21
#
#     accuracy                           0.92       189
#    macro avg       0.92      0.92      0.92       189
# weighted avg       0.92      0.92      0.92       189

# %%
model.save('audio_english_v1.h5')

# %%
def predict(audio):
    prob=model.predict(audio.reshape(1,8363,1))
    index=np.argmax(prob[0])
    return classes[index]

# %%
filepath='/media/m_snehith_reddy/Spider-Man/8th_Sem/Final_Year_Project/Testing/1_sec_cbn_kan_avanu_1.wav'

#reading the voice commands
samples, sample_rate = librosa.load(filepath, sr = 16000)
print(len(samples))
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples,rate=len(samples))  

predict(samples)
# Out:
# 16725
# 'Avanu'

# %%
import sounddevice as sd
samplerate = 16725
# the value below must be in seconds  
duration = 1.045
filename = 'recorded_audio.wav'
print("start")
mydata = sd.rec(int(samplerate * duration), samplerate=samplerate,
    channels=1, blocking=True)
print("end")
sd.wait()
sf.write(filename, mydata, samplerate)

# %%
print(history)
# Out:
# <tensorflow.python.keras.callbacks.History object at 0x7f6fb0596510>
