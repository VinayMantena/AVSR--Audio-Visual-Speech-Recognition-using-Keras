# %%
from os.path import isdir, join
from pathlib import Path
import pandas as pd

# Math
import numpy as np
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile
import librosa

from sklearn.decomposition import PCA

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import IPython.display as ipd
import librosa.display

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import pandas as pd

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import os
import librosa   #for audio processing
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile #for audio processing
import warnings
warnings.filterwarnings("ignore")

# %%
#English_Audio_Dataset About/1_sec_cbn_eng_about_2.wav
#Kannada_Audio_Dataset Avanu/1_sec_cbn_kan_avanu_1.wav
train_audio_path = '/media/m_snehith_reddy/Spider-Man/8th_Sem/Final_Year_Project/NEW_VIDEOS_AGAIN_DIVIDED_15_TEST_SIZE/Audio_only/train/'
filename = 'dog/1.wav'
sample_rate, samples = wavfile.read(str(train_audio_path) + filename)
# fig = plt.figure(figsize=(14, 8))
# ax1 = fig.add_subplot(211)
# ax1.set_title('Raw wave of ' + '../input/train/audio/yes/0a7c2a8d_nohash_0.wav')
# ax1.set_xlabel('time')
# ax1.set_ylabel('Amplitude')
#ax1.plot(np.linspace(0, sample_rate/len(samples), sample_rate), samples)
print(sample_rate)
print(len(samples))
# Out:
# 16000
# 16725

# %%
ipd.Audio(samples, rate=sample_rate)
print(sample_rate)
np.array(samples, dtype='float64')
# Out:
# 16000
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.],
#        ...,
#        [1., 0.],
#        [1., 1.],
#        [1., 1.]])

# %%
samples=np.array(samples, dtype='float64')

samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
labels=os.listdir(train_audio_path)

#find count of each label and plot bar graph
no_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    no_of_recordings.append(len(waves))
    
#plot
plt.figure(figsize=(30,5))
index = np.arange(len(labels))
plt.bar(index, no_of_recordings)
plt.xlabel('Commands', fontsize=12)
plt.ylabel('No of recordings', fontsize=12)
plt.xticks(index, labels, fontsize=15, rotation=60)
plt.title('No. of recordings for each command')
plt.show()

# %%
duration_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        sample_rate, samples = wavfile.read(train_audio_path + '/' + label + '/' + wav)
        duration_of_recordings.append(float(len(samples)/sample_rate))
    
plt.hist(np.array(duration_of_recordings))
# Out:
# (array([529.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([1.0453125 , 1.04958125, 1.05385   , 1.05811875, 1.0623875 ,
#         1.06665625, 1.070925  , 1.07519375, 1.0794625 , 1.08373125,
#         1.088     ]),
#  <BarContainer object of 10 artists>)

# %%
all_wave = []
all_label = []
dct = dict()
c=0
b=0
for label in labels:
    print(label)
    
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
#         samples, sample_rate = librosa.load(train_audio_path + '/' + label + '/' + wav, sr = 16000)
#         samples = librosa.resample(samples, sample_rate, 8000)
#         #print(len(samples))
#         dct[len(samples)] = dct.get(len(samples),0) + 1
#         b+=1
#         if(len(samples)== 8363):
            
#             c+=1
#             all_wave.append(samples)
#             all_label.append(label)
        X, sample_rate = librosa.load(train_audio_path + '/' + label + '/' + wav, sr = 16000)
        stft = np.abs(librosa.stft(X))
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
        chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
        mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
        contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
        tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X),sr=sample_rate).T,axis=0)
        feature_array = np.hstack([mfccs,chroma,mel,contrast,tonnetz])
        feature_vector  = np.around(feature_array,decimals=3)
        all_wave.append(feature_vector)
        all_label.append(label)
#print(dct)
print(dict(sorted(dct.items(), key=lambda item: item[1])))
print("len = ", len(dct))
print("c = ",c,b)
# Out:
# About
# bottle
# dog
# english
# good
# people
# today
# {}
# len =  0
# c =  0 0

# %%
print(len(all_wave))
# Out:
# 530

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y=le.fit_transform(all_label)
classes= list(le.classes_)

# %%
from keras.utils import np_utils
y=np_utils.to_categorical(y, num_classes=len(labels))

# %%
#all_wave = np.array(all_wave).reshape(-1,8363,1)

all_wave = np.array(all_wave).reshape(-1,193,)

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(np.array(all_wave),np.array(y),stratify=y,test_size = 0.3,train_size=0.7,random_state=777,shuffle=True)

# %%
y_val1 = list()
for i in y_val:
    count = 0
    for j in i:
        if( j == 1):
            y_val1.append(count);
        count +=1;

y_tr1 = list()
for i in y_tr:
    count = 0
    for j in i:
        if( j == 1):
            y_tr1.append(count);
        count +=1;

dct = dict()
for i in y_val1:
    dct[i] = dct.get(i,0) + 1
print(dict(sorted(dct.items(), key=lambda item: item[1])))

print("y_tr1 rows, cols =", len(y_tr1))
print("y_val1 rows, cols =", len(y_val1))
print("x_tr rows, cols =", len(x_tr), len(x_tr[0]))
print("x_val rows, cols =", len(x_val), len(x_val[0]))

# print("y_val1 =",y_val1)
x_train_dup = x_tr
y_train_dup = y_tr1

x_val_dup = x_val
y_val_dup = y_val1

# x_train_list = list(list())
# for i in range(0,len(x_tr)):
#     tmp = list()
#     for j in range(0,len(x_tr[i])):
#         tmp.append(x_tr[i][j])
#     x_train_list.append(tmp)
    
# print(x_train_list)
# print(x_tr)



dct = dict()
for i in range(0,9):
    count = 0
    tmp = list()
    for j in range(0, len(y_val1)):
        if(y_val1[j] == i):
            count +=1;
        if(count > 15 and y_val1[j] == i):
            x_train_dup = np.vstack([x_train_dup, x_val_dup[j]])
            y_train_dup = np.append(y_train_dup, y_val1[j])
            
            tmp.append(j)
    dct[i] = tmp

# print(len(x_train_dup), len(x_tr), len(y_train_dup), len(y_tr1))
# print(len(x_val_dup), len(x_val), len(y_val_dup), len(y_val1))
# #print(dct)
#print(dct.values())
index_list = list()
for i in dct.values():
    for j in i:
        index_list.append(j)
index_list.sort(reverse=True)
print(index_list)
for i in index_list:
    x_val_dup = np.delete(x_val_dup, (i), axis=0)
    y_val1.pop(i)
print(len(x_train_dup), len(x_tr), len(y_train_dup), len(y_tr1))
print(len(x_val_dup), len(x_val), len(y_val_dup), len(y_val1))





from keras.utils import np_utils, generic_utils

y_train_dup, y_val_dup = [np_utils.to_categorical(x) for x in (y_train_dup, y_val_dup)]
# Out:
# {1: 21, 2: 22, 6: 22, 5: 23, 0: 23, 3: 23, 4: 25}
# y_tr1 rows, cols = 371
# y_val1 rows, cols = 159
# x_tr rows, cols = 371 193
# x_val rows, cols = 159 193
# [158, 157, 156, 155, 154, 153, 152, 151, 150, 149, 148, 147, 146, 145, 144, 143, 142, 141, 140, 139, 138, 137, 136, 135, 134, 133, 132, 131, 130, 129, 128, 127, 126, 125, 124, 123, 122, 119, 118, 117, 116, 115, 114, 113, 112, 111, 109, 106, 105, 99, 91, 90, 88, 87]
# 425 371 425 371
# 105 159 105 105

# %%
from keras.layers import Dense, Dropout, Flatten, Conv1D, Input, MaxPooling1D, BatchNormalization, Bidirectional
from keras.models import Model, Sequential
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
K.clear_session()

# from keras.layers.core import Activation, Dropout, Dense
# from keras.layers import Flatten, LSTM

# model = Sequential()
# model.add(Dense(units=256, activation='relu', input_shape=(193,)))
# model.add(Dense(128, activation='relu'))
# model.add(Dense(128, activation="relu"))
# model.add(Dense(64, activation="relu"))
# model.add(Dense(9, activation='softmax'))
# model.summary()

inputs = Input(shape=(193,1))

# #First Conv1D layer
# conv = Conv1D(8,13, padding='valid', activation='relu', strides=1)(inputs)
# conv = MaxPooling1D(3)(conv)
# conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # conv = Dropout(0.3)(conv)

# #Second Conv1D layer
# conv = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # conv = Dropout(0.3)(conv)

# # #Third Conv1D layer
# # conv = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(conv)
# # conv = MaxPooling1D(3)(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # conv = Dropout(0.3)(conv)

# # #Fourth Conv1D layer
# # conv = Conv1D(64, 7, padding='valid', activation='relu', strides=1)(conv)
# # conv = MaxPooling1D(3)(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # conv = Dropout(0.3)(conv)



# #Flatten layer
# conv = Flatten()(conv)

# #Dense Layer 1
# conv = Dense(256, activation='relu')(conv)
# conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # conv = Dropout(0.3)(conv)

# # #Dense Layer 2
# # conv = Dense(512, activation='relu')(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # # conv = Dropout(0.3)(conv)

# # #Dense Layer 3
# # conv = Dense(1024, activation='relu')(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # # conv = Dropout(0.3)(conv)

# # #Dense Layer 4
# # conv = Dense(1024, activation='relu')(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# # # conv = Dropout(0.3)(conv)

# outputs = Dense(len(labels), activation='softmax')(conv)

# model = Model(inputs, outputs)
# model.summary()









conv = Conv1D(16,13, padding='valid', activation='relu', strides=1)(inputs)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)
conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
conv = Flatten()(conv)
x = Dense(units=1024, activation='relu')(conv)
x1 = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(x)
x1 = Dropout(0.3)(x1)
x1 = Dense(512, activation='relu')(x1)
x1 = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(x1)
x1 = Dropout(0.3)(x1)
x1 = Dense(256, activation='relu')(x1)
x1 = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(x1)
x1 = Dropout(0.3)(x1)
x1 = Dense(128, activation='relu')(x1)

outputs = Dense(len(labels), activation='softmax')(x1)

model = Model(inputs, outputs)
model.summary()












# #First Conv1D layer
# conv = Conv1D(8,13, padding='valid', activation='relu', strides=1)(inputs)
# conv = MaxPooling1D(3)(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# conv = Dropout(0.2)(conv)

# #Second Conv1D layer
# conv = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# conv = Dropout(0.2)(conv)

# #Third Conv1D layer
# conv = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# conv = Dropout(0.2)(conv)

# #Fourth Conv1D layer
# conv = Conv1D(64, 7, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# # conv = BatchNormalization(axis=-1,momentum=0.99,epsilon=0.001,center=True,scale=True,beta_initializer="zeros",gamma_initializer="ones",moving_mean_initializer="zeros",moving_variance_initializer="ones",beta_regularizer=None,gamma_regularizer=None,beta_constraint=None,gamma_constraint=None,renorm=False,renorm_clipping=None,renorm_momentum=0.99,fused=None,trainable=True,virtual_batch_size=None, adjustment=None, name=None)(conv)
# conv = Dropout(0.2)(conv)


# #Flatten layer
# conv = Flatten()(conv)

# #Dense Layer 1
# conv = Dense(1024, activation='relu')(conv)
# conv = Dropout(0.2)(conv)

# #Dense Layer 2
# conv = Dense(1024, activation='relu')(conv)
# conv = Dropout(0.2)(conv)

# # #Dense Layer 2
# # conv = Dense(32, activation='relu')(conv)
# # conv = Dropout(0.3)(conv)

# # #Dense Layer 2
# # conv = Dense(64, activation='relu')(conv)
# # conv = Dropout(0.3)(conv)

# outputs = Dense(len(labels), activation='softmax')(conv)

# model = Model(inputs, outputs)
# model.summary()


# #First Conv1D layer
# conv = Conv1D(8,13, padding='valid', activation='relu', strides=1)(inputs)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.3)(conv)

# #Second Conv1D layer
# conv = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.3)(conv)

# #Third Conv1D layer
# conv = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.3)(conv)

# #Fourth Conv1D layer
# conv = Conv1D(64, 7, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.3)(conv)

# #Flatten layer
# conv = Flatten()(conv)

# #Dense Layer 1
# conv = Dense(512, activation='relu')(conv)
# conv = Dropout(0.3)(conv)

# #Dense Layer 2
# conv = Dense(128, activation='relu')(conv)
# conv = Dropout(0.3)(conv)

# #Dense Layer 2
# conv = Dense(64, activation='relu')(conv)
# conv = Dropout(0.3)(conv)

# outputs = Dense(len(labels), activation='softmax')(conv)

# model = Model(inputs, outputs)
# model.summary()


# #First Conv1D layer
# conv = Conv1D(8,13, padding='valid', activation='relu', strides=1)(inputs)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.2)(conv)

# #Second Conv1D layer
# conv = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.2)(conv)

# #Third Conv1D layer
# conv = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.2)(conv)

# #Fourth Conv1D layer
# conv = Conv1D(64, 7, padding='valid', activation='relu', strides=1)(conv)
# conv = MaxPooling1D(3)(conv)
# conv = Dropout(0.2)(conv)

# #Flatten layer
# conv = Flatten()(conv)

# #Dense Layer 1
# conv = Dense(256, activation='relu')(conv)
# conv = Dropout(0.2)(conv)

# #Dense Layer 2
# conv = Dense(128, activation='relu')(conv)
# conv = Dropout(0.2)(conv)

# outputs = Dense(len(labels), activation='softmax')(conv)

# model = Model(inputs, outputs)
# model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 193, 1)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 181, 16)           224
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 60, 16)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 16)            0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 60, 16)            64
# _________________________________________________________________
# flatten (Flatten)            (None, 960)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              984064
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 1,681,447
# Trainable params: 1,677,831
# Non-trainable params: 3,616
# _________________________________________________________________

# %%
import keras
optimizer = keras.optimizers.Adam(lr=0.001)
model.compile(loss='categorical_crossentropy',optimizer= 'adam',metrics=['accuracy'])

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.0001) 
mc = ModelCheckpoint('best_model.hdf5', monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history=model.fit(x_train_dup, y_train_dup ,epochs=200, batch_size=32, validation_data=(x_val_dup,y_val_dup))
# Out:
# Epoch 1/200
# 14/14 [==============================] - 2s 53ms/step - loss: 2.4048 - accuracy: 0.1614 - val_loss: 2.9048 - val_accuracy: 0.1429
# Epoch 2/200
# 14/14 [==============================] - 0s 18ms/step - loss: 1.9456 - accuracy: 0.2947 - val_loss: 3.0558 - val_accuracy: 0.1143
# Epoch 3/200
# 14/14 [==============================] - 0s 18ms/step - loss: 1.7335 - accuracy: 0.3450 - val_loss: 2.7397 - val_accuracy: 0.1714
# Epoch 4/200
# 14/14 [==============================] - 0s 18ms/step - loss: 1.6096 - accuracy: 0.4471 - val_loss: 1.9792 - val_accuracy: 0.2381
# Epoch 5/200
# 14/14 [==============================] - 0s 17ms/step - loss: 1.4257 - accuracy: 0.4520 - val_loss: 1.8441 - val_accuracy: 0.3238
# Epoch 6/200
# 14/14 [==============================] - 0s 18ms/step - loss: 1.3163 - accuracy: 0.4857 - val_loss: 1.5177 - val_accuracy: 0.3905
# Epoch 7/200
# 14/14 [==============================] - 0s 17ms/step - loss: 1.2329 - accuracy: 0.5348 - val_loss: 1.4699 - val_accuracy: 0.3905
# Epoch 8/200
# 14/14 [==============================] - 0s 18ms/step - loss: 1.2009 - accuracy: 0.5215 - val_loss: 1.2395 - val_accuracy: 0.4286
# Epoch 9/200
# 14/14 [==============================] - 0s 17ms/step - loss: 1.0149 - accuracy: 0.6101 - val_loss: 1.3971 - val_accuracy: 0.4476
# Epoch 10/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.9884 - accuracy: 0.6179 - val_loss: 1.0331 - val_accuracy: 0.5048
# Epoch 11/200
# 14/14 [==============================] - 0s 19ms/step - loss: 1.0147 - accuracy: 0.6039 - val_loss: 0.7882 - val_accuracy: 0.6857
# Epoch 12/200
# 14/14 [==============================] - 0s 18ms/step - loss: 1.0753 - accuracy: 0.6310 - val_loss: 0.6281 - val_accuracy: 0.7905
# Epoch 13/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.8547 - accuracy: 0.6749 - val_loss: 0.5857 - val_accuracy: 0.8286
# Epoch 14/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.9914 - accuracy: 0.6072 - val_loss: 0.5291 - val_accuracy: 0.8476
# Epoch 15/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.8477 - accuracy: 0.6768 - val_loss: 0.5107 - val_accuracy: 0.8381
# Epoch 16/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.9458 - accuracy: 0.6651 - val_loss: 0.5095 - val_accuracy: 0.8000
# Epoch 17/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.8080 - accuracy: 0.6863 - val_loss: 0.4947 - val_accuracy: 0.8381
# Epoch 18/200
# 14/14 [==============================] - 0s 26ms/step - loss: 0.7941 - accuracy: 0.6806 - val_loss: 0.4773 - val_accuracy: 0.8381
# Epoch 19/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.7169 - accuracy: 0.7379 - val_loss: 0.4717 - val_accuracy: 0.8286
# Epoch 20/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.7677 - accuracy: 0.7067 - val_loss: 0.5211 - val_accuracy: 0.8190
# Epoch 21/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.6362 - accuracy: 0.7358 - val_loss: 0.4429 - val_accuracy: 0.8857
# Epoch 22/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.6716 - accuracy: 0.7510 - val_loss: 0.4120 - val_accuracy: 0.8857
# Epoch 23/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.7381 - accuracy: 0.7583 - val_loss: 0.4663 - val_accuracy: 0.8381
# Epoch 24/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.5837 - accuracy: 0.7718 - val_loss: 0.4648 - val_accuracy: 0.8286
# Epoch 25/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.6315 - accuracy: 0.7713 - val_loss: 0.4075 - val_accuracy: 0.8762
# Epoch 26/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.5634 - accuracy: 0.8188 - val_loss: 0.4195 - val_accuracy: 0.8571
# Epoch 27/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.6272 - accuracy: 0.7698 - val_loss: 0.3670 - val_accuracy: 0.8571
# Epoch 28/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.6141 - accuracy: 0.7674 - val_loss: 0.3615 - val_accuracy: 0.8762
# Epoch 29/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.5609 - accuracy: 0.7928 - val_loss: 0.4865 - val_accuracy: 0.7810
# Epoch 30/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.5722 - accuracy: 0.7878 - val_loss: 0.5126 - val_accuracy: 0.8286
# Epoch 31/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.4445 - accuracy: 0.8244 - val_loss: 0.5355 - val_accuracy: 0.8571
# Epoch 32/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.4489 - accuracy: 0.8472 - val_loss: 0.4177 - val_accuracy: 0.8381
# Epoch 33/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.4788 - accuracy: 0.8298 - val_loss: 0.4267 - val_accuracy: 0.8571
# Epoch 34/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.4707 - accuracy: 0.8523 - val_loss: 0.3568 - val_accuracy: 0.9048
# Epoch 35/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.5689 - accuracy: 0.8170 - val_loss: 0.3593 - val_accuracy: 0.9333
# Epoch 36/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.5020 - accuracy: 0.8214 - val_loss: 0.3985 - val_accuracy: 0.8762
# Epoch 37/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.4730 - accuracy: 0.8070 - val_loss: 0.3699 - val_accuracy: 0.8857
# Epoch 38/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.4847 - accuracy: 0.8047 - val_loss: 0.4078 - val_accuracy: 0.8571
# Epoch 39/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.5063 - accuracy: 0.8382 - val_loss: 0.3972 - val_accuracy: 0.8952
# Epoch 40/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3982 - accuracy: 0.8621 - val_loss: 0.4146 - val_accuracy: 0.8571
# Epoch 41/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.4746 - accuracy: 0.8432 - val_loss: 0.3570 - val_accuracy: 0.8952
# Epoch 42/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3623 - accuracy: 0.8802 - val_loss: 0.3898 - val_accuracy: 0.8667
# Epoch 43/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.4497 - accuracy: 0.8314 - val_loss: 0.3851 - val_accuracy: 0.8762
# Epoch 44/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3976 - accuracy: 0.8322 - val_loss: 0.4344 - val_accuracy: 0.8476
# Epoch 45/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3161 - accuracy: 0.8912 - val_loss: 0.3908 - val_accuracy: 0.8952
# Epoch 46/200
# 14/14 [==============================] - 0s 26ms/step - loss: 0.4656 - accuracy: 0.8272 - val_loss: 0.3333 - val_accuracy: 0.9143
# Epoch 47/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.4086 - accuracy: 0.8577 - val_loss: 0.3111 - val_accuracy: 0.8857
# Epoch 48/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3760 - accuracy: 0.8821 - val_loss: 0.3130 - val_accuracy: 0.8857
# Epoch 49/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3143 - accuracy: 0.8791 - val_loss: 0.3773 - val_accuracy: 0.8857
# Epoch 50/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3415 - accuracy: 0.8704 - val_loss: 0.3702 - val_accuracy: 0.8762
# Epoch 51/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.2857 - accuracy: 0.8839 - val_loss: 0.3608 - val_accuracy: 0.8762
# Epoch 52/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3654 - accuracy: 0.8669 - val_loss: 0.3911 - val_accuracy: 0.9238
# Epoch 53/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.2697 - accuracy: 0.8853 - val_loss: 0.4007 - val_accuracy: 0.9143
# Epoch 54/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3053 - accuracy: 0.8616 - val_loss: 0.3864 - val_accuracy: 0.8857
# Epoch 55/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.2902 - accuracy: 0.9019 - val_loss: 0.4090 - val_accuracy: 0.8857
# Epoch 56/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.3659 - accuracy: 0.8651 - val_loss: 0.4300 - val_accuracy: 0.8571
# Epoch 57/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.3255 - accuracy: 0.8739 - val_loss: 0.3662 - val_accuracy: 0.8952
# Epoch 58/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3195 - accuracy: 0.8742 - val_loss: 0.3697 - val_accuracy: 0.8571
# Epoch 59/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3311 - accuracy: 0.9035 - val_loss: 0.3489 - val_accuracy: 0.8857
# Epoch 60/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2726 - accuracy: 0.8985 - val_loss: 0.3667 - val_accuracy: 0.8857
# Epoch 61/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3685 - accuracy: 0.8786 - val_loss: 0.3759 - val_accuracy: 0.8952
# Epoch 62/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2744 - accuracy: 0.8910 - val_loss: 0.4375 - val_accuracy: 0.8476
# Epoch 63/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2795 - accuracy: 0.9134 - val_loss: 0.4232 - val_accuracy: 0.8762
# Epoch 64/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2812 - accuracy: 0.9053 - val_loss: 0.4131 - val_accuracy: 0.8667
# Epoch 65/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3398 - accuracy: 0.8831 - val_loss: 0.4570 - val_accuracy: 0.8571
# Epoch 66/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2913 - accuracy: 0.8763 - val_loss: 0.3434 - val_accuracy: 0.9238
# Epoch 67/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2723 - accuracy: 0.9058 - val_loss: 0.3861 - val_accuracy: 0.9048
# Epoch 68/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3396 - accuracy: 0.8635 - val_loss: 0.3383 - val_accuracy: 0.9048
# Epoch 69/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.3160 - accuracy: 0.9039 - val_loss: 0.3943 - val_accuracy: 0.8857
# Epoch 70/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3019 - accuracy: 0.8708 - val_loss: 0.3496 - val_accuracy: 0.9143
# Epoch 71/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3316 - accuracy: 0.8821 - val_loss: 0.3429 - val_accuracy: 0.8857
# Epoch 72/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.2693 - accuracy: 0.9078 - val_loss: 0.3171 - val_accuracy: 0.9143
# Epoch 73/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.2659 - accuracy: 0.9186 - val_loss: 0.3175 - val_accuracy: 0.9238
# Epoch 74/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3346 - accuracy: 0.8836 - val_loss: 0.3411 - val_accuracy: 0.9238
# Epoch 75/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2045 - accuracy: 0.9391 - val_loss: 0.3663 - val_accuracy: 0.8762
# Epoch 76/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3132 - accuracy: 0.8865 - val_loss: 0.3009 - val_accuracy: 0.8667
# Epoch 77/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2572 - accuracy: 0.9181 - val_loss: 0.2591 - val_accuracy: 0.9143
# Epoch 78/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3221 - accuracy: 0.9080 - val_loss: 0.2396 - val_accuracy: 0.9429
# Epoch 79/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1982 - accuracy: 0.9383 - val_loss: 0.2826 - val_accuracy: 0.9333
# Epoch 80/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3052 - accuracy: 0.8973 - val_loss: 0.2977 - val_accuracy: 0.9333
# Epoch 81/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2061 - accuracy: 0.9243 - val_loss: 0.2498 - val_accuracy: 0.9333
# Epoch 82/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.2642 - accuracy: 0.8859 - val_loss: 0.2500 - val_accuracy: 0.9048
# Epoch 83/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2513 - accuracy: 0.9282 - val_loss: 0.3095 - val_accuracy: 0.9143
# Epoch 84/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.2097 - accuracy: 0.9372 - val_loss: 0.2972 - val_accuracy: 0.9238
# Epoch 85/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1723 - accuracy: 0.9341 - val_loss: 0.2449 - val_accuracy: 0.9333
# Epoch 86/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.2409 - accuracy: 0.9051 - val_loss: 0.2861 - val_accuracy: 0.9238
# Epoch 87/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2643 - accuracy: 0.9120 - val_loss: 0.3339 - val_accuracy: 0.9048
# Epoch 88/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2340 - accuracy: 0.9134 - val_loss: 0.2895 - val_accuracy: 0.9333
# Epoch 89/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1845 - accuracy: 0.9455 - val_loss: 0.3489 - val_accuracy: 0.9333
# Epoch 90/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1949 - accuracy: 0.9405 - val_loss: 0.3858 - val_accuracy: 0.8857
# Epoch 91/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3056 - accuracy: 0.9016 - val_loss: 0.4003 - val_accuracy: 0.8571
# Epoch 92/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2130 - accuracy: 0.9075 - val_loss: 0.3937 - val_accuracy: 0.9143
# Epoch 93/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1988 - accuracy: 0.9218 - val_loss: 0.4977 - val_accuracy: 0.9048
# Epoch 94/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2312 - accuracy: 0.9063 - val_loss: 0.5020 - val_accuracy: 0.9048
# Epoch 95/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2717 - accuracy: 0.8997 - val_loss: 0.4887 - val_accuracy: 0.9143
# Epoch 96/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1564 - accuracy: 0.9324 - val_loss: 0.4066 - val_accuracy: 0.8857
# Epoch 97/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1971 - accuracy: 0.9234 - val_loss: 0.4709 - val_accuracy: 0.8667
# Epoch 98/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2309 - accuracy: 0.9162 - val_loss: 0.4648 - val_accuracy: 0.8952
# Epoch 99/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2021 - accuracy: 0.9398 - val_loss: 0.3739 - val_accuracy: 0.9143
# Epoch 100/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2895 - accuracy: 0.9008 - val_loss: 0.3208 - val_accuracy: 0.9238
# Epoch 101/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1742 - accuracy: 0.9354 - val_loss: 0.3016 - val_accuracy: 0.9048
# Epoch 102/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1830 - accuracy: 0.9512 - val_loss: 0.3173 - val_accuracy: 0.9238
# Epoch 103/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2050 - accuracy: 0.9244 - val_loss: 0.3492 - val_accuracy: 0.9143
# Epoch 104/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2044 - accuracy: 0.9278 - val_loss: 0.3978 - val_accuracy: 0.9143
# Epoch 105/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2077 - accuracy: 0.9315 - val_loss: 0.3576 - val_accuracy: 0.9048
# Epoch 106/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2417 - accuracy: 0.9072 - val_loss: 0.3299 - val_accuracy: 0.9048
# Epoch 107/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2184 - accuracy: 0.9364 - val_loss: 0.3645 - val_accuracy: 0.9143
# Epoch 108/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2215 - accuracy: 0.9226 - val_loss: 0.4074 - val_accuracy: 0.8857
# Epoch 109/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.2123 - accuracy: 0.9193 - val_loss: 0.5113 - val_accuracy: 0.8762
# Epoch 110/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2211 - accuracy: 0.9252 - val_loss: 0.5193 - val_accuracy: 0.8762
# Epoch 111/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1948 - accuracy: 0.9426 - val_loss: 0.4583 - val_accuracy: 0.8952
# Epoch 112/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1684 - accuracy: 0.9551 - val_loss: 0.4007 - val_accuracy: 0.8952
# Epoch 113/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1347 - accuracy: 0.9529 - val_loss: 0.3819 - val_accuracy: 0.8762
# Epoch 114/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1782 - accuracy: 0.9271 - val_loss: 0.4077 - val_accuracy: 0.9048
# Epoch 115/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1781 - accuracy: 0.9313 - val_loss: 0.4421 - val_accuracy: 0.8762
# Epoch 116/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1984 - accuracy: 0.9428 - val_loss: 0.3536 - val_accuracy: 0.9048
# Epoch 117/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2001 - accuracy: 0.9179 - val_loss: 0.3509 - val_accuracy: 0.9143
# Epoch 118/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1930 - accuracy: 0.9301 - val_loss: 0.3164 - val_accuracy: 0.9143
# Epoch 119/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2482 - accuracy: 0.9072 - val_loss: 0.3026 - val_accuracy: 0.9143
# Epoch 120/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2235 - accuracy: 0.9275 - val_loss: 0.3000 - val_accuracy: 0.9238
# Epoch 121/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1581 - accuracy: 0.9385 - val_loss: 0.3567 - val_accuracy: 0.9143
# Epoch 122/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2130 - accuracy: 0.9123 - val_loss: 0.3869 - val_accuracy: 0.9143
# Epoch 123/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1473 - accuracy: 0.9489 - val_loss: 0.3806 - val_accuracy: 0.9333
# Epoch 124/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1309 - accuracy: 0.9459 - val_loss: 0.4632 - val_accuracy: 0.8857
# Epoch 125/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.2005 - accuracy: 0.9410 - val_loss: 0.4322 - val_accuracy: 0.9238
# Epoch 126/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1217 - accuracy: 0.9510 - val_loss: 0.4123 - val_accuracy: 0.9333
# Epoch 127/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1199 - accuracy: 0.9429 - val_loss: 0.4012 - val_accuracy: 0.9238
# Epoch 128/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0968 - accuracy: 0.9760 - val_loss: 0.3906 - val_accuracy: 0.9143
# Epoch 129/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1915 - accuracy: 0.9348 - val_loss: 0.4213 - val_accuracy: 0.8952
# Epoch 130/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.2456 - accuracy: 0.9065 - val_loss: 0.3823 - val_accuracy: 0.9143
# Epoch 131/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1900 - accuracy: 0.9463 - val_loss: 0.2436 - val_accuracy: 0.9333
# Epoch 132/200
# 14/14 [==============================] - 0s 26ms/step - loss: 0.1971 - accuracy: 0.9348 - val_loss: 0.3323 - val_accuracy: 0.9048
# Epoch 133/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1327 - accuracy: 0.9525 - val_loss: 0.3313 - val_accuracy: 0.9048
# Epoch 134/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.2511 - accuracy: 0.9247 - val_loss: 0.4208 - val_accuracy: 0.8952
# Epoch 135/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1018 - accuracy: 0.9713 - val_loss: 0.3919 - val_accuracy: 0.8952
# Epoch 136/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.2198 - accuracy: 0.8986 - val_loss: 0.3327 - val_accuracy: 0.8762
# Epoch 137/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1383 - accuracy: 0.9553 - val_loss: 0.3366 - val_accuracy: 0.8571
# Epoch 138/200
# 14/14 [==============================] - 0s 22ms/step - loss: 0.1718 - accuracy: 0.9387 - val_loss: 0.4550 - val_accuracy: 0.8667
# Epoch 139/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.1944 - accuracy: 0.9289 - val_loss: 0.4189 - val_accuracy: 0.9048
# Epoch 140/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1604 - accuracy: 0.9504 - val_loss: 0.3869 - val_accuracy: 0.9048
# Epoch 141/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1049 - accuracy: 0.9711 - val_loss: 0.3178 - val_accuracy: 0.9143
# Epoch 142/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1117 - accuracy: 0.9596 - val_loss: 0.2572 - val_accuracy: 0.9333
# Epoch 143/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1193 - accuracy: 0.9613 - val_loss: 0.3102 - val_accuracy: 0.9048
# Epoch 144/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1398 - accuracy: 0.9572 - val_loss: 0.3068 - val_accuracy: 0.9238
# Epoch 145/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1627 - accuracy: 0.9500 - val_loss: 0.3997 - val_accuracy: 0.9143
# Epoch 146/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1368 - accuracy: 0.9537 - val_loss: 0.3412 - val_accuracy: 0.9143
# Epoch 147/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1143 - accuracy: 0.9481 - val_loss: 0.3571 - val_accuracy: 0.9143
# Epoch 148/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1298 - accuracy: 0.9529 - val_loss: 0.4069 - val_accuracy: 0.8762
# Epoch 149/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1326 - accuracy: 0.9513 - val_loss: 0.4657 - val_accuracy: 0.8857
# Epoch 150/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1447 - accuracy: 0.9387 - val_loss: 0.4353 - val_accuracy: 0.8667
# Epoch 151/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1496 - accuracy: 0.9605 - val_loss: 0.3719 - val_accuracy: 0.9048
# Epoch 152/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1056 - accuracy: 0.9726 - val_loss: 0.3547 - val_accuracy: 0.9048
# Epoch 153/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1290 - accuracy: 0.9576 - val_loss: 0.3708 - val_accuracy: 0.9048
# Epoch 154/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1419 - accuracy: 0.9456 - val_loss: 0.3250 - val_accuracy: 0.9238
# Epoch 155/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1418 - accuracy: 0.9455 - val_loss: 0.3373 - val_accuracy: 0.8857
# Epoch 156/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2383 - accuracy: 0.9237 - val_loss: 0.4658 - val_accuracy: 0.8762
# Epoch 157/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1146 - accuracy: 0.9654 - val_loss: 0.5070 - val_accuracy: 0.8762
# Epoch 158/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1487 - accuracy: 0.9634 - val_loss: 0.4281 - val_accuracy: 0.8857
# Epoch 159/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1520 - accuracy: 0.9560 - val_loss: 0.4048 - val_accuracy: 0.9048
# Epoch 160/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1819 - accuracy: 0.9440 - val_loss: 0.3937 - val_accuracy: 0.9048
# Epoch 161/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1176 - accuracy: 0.9578 - val_loss: 0.3516 - val_accuracy: 0.9143
# Epoch 162/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1584 - accuracy: 0.9536 - val_loss: 0.4003 - val_accuracy: 0.8762
# Epoch 163/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1443 - accuracy: 0.9530 - val_loss: 0.3966 - val_accuracy: 0.8857
# Epoch 164/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1875 - accuracy: 0.9403 - val_loss: 0.5667 - val_accuracy: 0.8762
# Epoch 165/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2117 - accuracy: 0.9362 - val_loss: 0.4165 - val_accuracy: 0.8571
# Epoch 166/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1391 - accuracy: 0.9390 - val_loss: 0.3625 - val_accuracy: 0.8952
# Epoch 167/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1404 - accuracy: 0.9412 - val_loss: 0.3055 - val_accuracy: 0.9143
# Epoch 168/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0820 - accuracy: 0.9708 - val_loss: 0.3206 - val_accuracy: 0.8952
# Epoch 169/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0732 - accuracy: 0.9803 - val_loss: 0.3312 - val_accuracy: 0.8857
# Epoch 170/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1487 - accuracy: 0.9545 - val_loss: 0.3235 - val_accuracy: 0.8857
# Epoch 171/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1329 - accuracy: 0.9458 - val_loss: 0.3540 - val_accuracy: 0.8667
# Epoch 172/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1205 - accuracy: 0.9659 - val_loss: 0.3142 - val_accuracy: 0.9048
# Epoch 173/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1298 - accuracy: 0.9561 - val_loss: 0.3297 - val_accuracy: 0.9048
# Epoch 174/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0950 - accuracy: 0.9649 - val_loss: 0.3417 - val_accuracy: 0.8952
# Epoch 175/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1122 - accuracy: 0.9627 - val_loss: 0.2928 - val_accuracy: 0.9238
# Epoch 176/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1113 - accuracy: 0.9516 - val_loss: 0.3265 - val_accuracy: 0.9238
# Epoch 177/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0968 - accuracy: 0.9594 - val_loss: 0.3553 - val_accuracy: 0.9143
# Epoch 178/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1065 - accuracy: 0.9595 - val_loss: 0.4044 - val_accuracy: 0.8667
# Epoch 179/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1068 - accuracy: 0.9634 - val_loss: 0.3808 - val_accuracy: 0.8857
# Epoch 180/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1961 - accuracy: 0.9160 - val_loss: 0.3815 - val_accuracy: 0.9048
# Epoch 181/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1650 - accuracy: 0.9537 - val_loss: 0.3992 - val_accuracy: 0.9143
# Epoch 182/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0969 - accuracy: 0.9713 - val_loss: 0.4312 - val_accuracy: 0.9048
# Epoch 183/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1058 - accuracy: 0.9680 - val_loss: 0.4146 - val_accuracy: 0.9143
# Epoch 184/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1425 - accuracy: 0.9598 - val_loss: 0.4150 - val_accuracy: 0.8762
# Epoch 185/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1227 - accuracy: 0.9505 - val_loss: 0.3760 - val_accuracy: 0.9048
# Epoch 186/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0829 - accuracy: 0.9687 - val_loss: 0.3339 - val_accuracy: 0.9238
# Epoch 187/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0733 - accuracy: 0.9739 - val_loss: 0.3557 - val_accuracy: 0.9238
# Epoch 188/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.2125 - accuracy: 0.9266 - val_loss: 0.2930 - val_accuracy: 0.9238
# Epoch 189/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1080 - accuracy: 0.9726 - val_loss: 0.3259 - val_accuracy: 0.9048
# Epoch 190/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1601 - accuracy: 0.9319 - val_loss: 0.3243 - val_accuracy: 0.9238
# Epoch 191/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1216 - accuracy: 0.9619 - val_loss: 0.3626 - val_accuracy: 0.9238
# Epoch 192/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1462 - accuracy: 0.9471 - val_loss: 0.3827 - val_accuracy: 0.8952
# Epoch 193/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1127 - accuracy: 0.9652 - val_loss: 0.4256 - val_accuracy: 0.8667
# Epoch 194/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1969 - accuracy: 0.9394 - val_loss: 0.3770 - val_accuracy: 0.8762
# Epoch 195/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0941 - accuracy: 0.9651 - val_loss: 0.3379 - val_accuracy: 0.8952
# Epoch 196/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0992 - accuracy: 0.9634 - val_loss: 0.3087 - val_accuracy: 0.9143
# Epoch 197/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1130 - accuracy: 0.9649 - val_loss: 0.3203 - val_accuracy: 0.9143
# Epoch 198/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1252 - accuracy: 0.9596 - val_loss: 0.3632 - val_accuracy: 0.9143
# Epoch 199/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1355 - accuracy: 0.9487 - val_loss: 0.4554 - val_accuracy: 0.8952
# Epoch 200/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1254 - accuracy: 0.9662 - val_loss: 0.4187 - val_accuracy: 0.9048

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('Audio_English Model accuracy.jpg')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train_loss', 'val_loss'], loc='upper right')
plt.savefig('Audio_English Model Loss.jpg')
plt.show()

# %%
predict_prob=model.predict(x_val_dup)
predict_classes=np.argmax(predict_prob,axis=1)
predict_classes
score, acc = model.evaluate(x_val_dup, y_val_dup)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4187 - accuracy: 0.9048

# %%
tmp = list()
for i in y_val_dup:
    count = 0
    for j in i:
        if( j == 1):
            tmp.append(count);
        count +=1;
# print(tmp)
from sklearn.preprocessing import LabelEncoder
from keras.models import load_model
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
import seaborn as sns
words_list = ['About', 'Bottle', 'Dog','English', 'Good','People', 'Today']
lb_make = LabelEncoder()
y_pred = lb_make.fit_transform(predict_classes)
Y_Test = lb_make.fit_transform(tmp)
cm = confusion_matrix(Y_Test, y_pred)
cm_df = pd.DataFrame(cm,index =words_list,columns = words_list)
plt.figure(figsize=(10,8))
sns.heatmap(cm_df, annot=True, cmap="Blues")
plt.title('Test accuracy of English dataset {}'.format(acc))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.savefig('Audio_English Confusion Matrix.jpg')
plt.show()

# %%
from sklearn.metrics import classification_report
y_pred = lb_make.fit_transform(predict_classes)
Y_Test = lb_make.fit_transform(Y_Test)
print(classification_report(Y_Test, y_pred, target_names=words_list))
# Out:
#               precision    recall  f1-score   support
#
#        About       0.86      0.80      0.83        15
#       Bottle       0.93      0.87      0.90        15
#          Dog       0.81      0.87      0.84        15
#      English       1.00      1.00      1.00        15
#         Good       1.00      0.93      0.97        15
#       People       1.00      0.87      0.93        15
#        Today       0.79      1.00      0.88        15
#
#     accuracy                           0.90       105
#    macro avg       0.91      0.90      0.91       105
# weighted avg       0.91      0.90      0.91       105

# %%
model.save('audio_english_v1.h5')

# %%
def predict(audio):
    prob=model.predict(audio.reshape(1,8363,1))
    index=np.argmax(prob[0])
    return classes[index]

# %%
filepath='/media/m_snehith_reddy/Spider-Man/8th_Sem/Final_Year_Project/Testing/1_sec_cbn_kan_avanu_1.wav'

#reading the voice commands
samples, sample_rate = librosa.load(filepath, sr = 16000)
print(len(samples))
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples,rate=len(samples))  

predict(samples)
# Out:
# 16725
# 'Avanu'

# %%
import sounddevice as sd
samplerate = 16725
# the value below must be in seconds  
duration = 1.045
filename = 'recorded_audio.wav'
print("start")
mydata = sd.rec(int(samplerate * duration), samplerate=samplerate,
    channels=1, blocking=True)
print("end")
sd.wait()
sf.write(filename, mydata, samplerate)

# %%
print(history)
# Out:
# <tensorflow.python.keras.callbacks.History object at 0x7f6fb0596510>
